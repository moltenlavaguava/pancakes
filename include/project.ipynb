# %% [markdown]
# # Work on projects here!
#
# This is just a sample Jupyter Notebook. Create more by making a new file with a `.ipynb` extension!
#
# If prompted, make sure to install `ipykernel` and/or `pip` so you can run this file.
# - *Note: just like with every other package, these can be installed more quickly by manually running `uv pip install ipykernel` in the VS Code terminal.*

# %%
# Code goes here
print("Hello, world!")
# Out:
# Hello, world!
